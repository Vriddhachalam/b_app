# %%
print("hi")
# Out:
# hi

# %%
import json 

with open("assets/songs.json", "r", encoding="utf-8") as f:
    data = json.load(f)
print(data.keys())
items = json.loads(data["data"])
print(items[:1])


title_to_find = "Jaya Sri Ganesha Vighna Nasha"

filtered = [
    song for song in items
    if title_to_find in song.get("title", "")
]

print(filtered)
# Out:
# dict_keys(['success', 'data'])
# [{'song_id': '3607', 'title': '(Namo) Devi Durga Janani', 'title2': '(Namo) Devi Durga Janani Devi Amba Bhavani ', 'lyrics': 'Jaya Ma, Jaya Ma\nJaya Karunamayi Ma\nAbhaya Pradayini Ma [ Devi Durga ... ]\nDeva Sambhuta Shakthi Swaroopini\nAbhayankari Devi Narayani\nJaya Ma, Jaya Ma, Jaya Ma, Sai Ma\nJaya Ma, Jaya Ma, Sai Ma', 'meaning': '<p>I pray to Mother Durga,&nbsp;the Divine Mother.&nbsp;She is&nbsp;Mother Ambe, born out of the flame that&nbsp;emanated from the bodies of Brahma, Vishnu and Shiva. She is full of compassion and gives us courage, protection and joy. I sing to You, O Divine Mother, and praise Your Supreme Power and Form in Mother&nbsp;Sai.</p>\r\n\r\n', 'language': 'sanskrit / hindi', 'deity': 'devi', 'raga': '~ hamsadhwani', 'beat': '8 beat / keherwa / adi', 'tempo': 'medium', 'level': 'advanced', 'audio_link': ['https://sairhythms.org/sites/default/files/pages/songs/audio/namo-devi-durga-janani.mp3'], 'video_link': [], 'golden_voice': [], 'songtags': '', 'ulink': 'zASD', 'url': '/song/namo-devi-durga-janani', 'ts': 'November 07 2025 08:20:21'}]
# [{'song_id': '1210', 'title': 'Jaya Sri Ganesha Vighna Nasha', 'title2': 'Jaya Sri Ganesha Vighna Nasha Gajanana', 'lyrics': 'Vidya Buddhi Sarva Siddhi Suranjana [ Jaya Sri ... ]\nJaya Heramba Sri Jagadamba Nandana\nEka Dantha Dayavantha Shubhanana\nMangala Dayaka Sri Vinayaka Vandana\n', 'meaning': 'Glory to the Lord of Ganaas, Ganesha, the\xa0destroyer of obstacles, who has the head of an elephant, who confers scholarship, intelligence and\xa0power. Glory to the son of Universal Mother (Parvathi). Glory to the one who is\xa0single tusked, compassionate\xa0and who\xa0bestows\xa0auspiciousness. I bow to Thee who is the highest.', 'language': 'sanskrit / hindi', 'deity': 'ganesha', 'raga': 'miyan ki malhar', 'beat': '7 beat / rupak / misrachapu', 'tempo': 'medium', 'level': 'advanced', 'audio_link': ['https://sairhythms.org/sites/default/files/pages/songs/audio/jaya-sri-ganesha-vighna-nasha.mp3'], 'video_link': ['https://youtu.be/pqgGpCGcyT0'], 'golden_voice': [], 'songtags': 'lead-music, sheet-music', 'ulink': 'sRqU', 'url': '/song/jaya-sri-ganesha-vighna-nasha'}]
